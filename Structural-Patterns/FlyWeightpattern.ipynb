# %% [markdown]
# # FlyWeight Design pattern

# %% [markdown]
# ### Step 1: Define the shared Flyweight: TreeType

# %%
class TreeType:

    def __init__(self, name, color, texture):
        self.name = name
        self.color = color
        self.texture = texture

    def draw(self, x, y):
        print(f"Drawing a {self.name} tree at ({x}, {y}) with color {self.color} and texture '{self.texture}'")

# %% [markdown]
# ### Step 2: Create the Flyweight Factory

# %%
class TreeFactory:
    _tree_types = {}

    @classmethod
    def get_tree_type(cls, name, color, texture):
        key = (name, color, texture)
        if key not in cls._tree_types:
            cls._tree_types[key] = TreeType(name, color, texture)
        return cls._tree_types[key]

# %% [markdown]
# ### Step 3: Tree Class (Stores Only Extrinsic State)

# %%
class Tree:

    def __init__(self, x, y, tree_type):
        self.x = x
        self.y = y
        self.tree_type = tree_type

    def draw(self):
        self.tree_type.draw(self.x, self.y)

# %% [markdown]
# ### Step 4: Forest to Manage Trees

# %%
class Forest:

    def __init__(self):
        self.trees = []

    def plant_tree(self, x, y, name, color, texture):
        tree_type = TreeFactory.get_tree_type(name, color, texture)
        tree = Tree(x, y, tree_type)
        self.trees.append(tree)

    def draw_forest(self):
        for tree in self.trees:
            tree.draw()

# %% [markdown]
# ### Step 5: Client Code

# %%
if __name__ == "__main__":
    import random
    
    forest = Forest()

    for _ in range(100):
        x, y = random.randint(0, 100), random.randint(0, 100)
        forest.plant_tree(x, y, "Oak", "Green", "Rough")
    
    for _ in range(100):
        x, y = random.randint(0, 100), random.randint(0, 100)
        forest.plant_tree(x, y, "Pine", "Dark Green", "Pointy")

    forest.draw_forest()
# Out:
# Drawing a Oak tree at (87, 46) with color Green and texture 'Rough'
# Drawing a Oak tree at (79, 100) with color Green and texture 'Rough'
# Drawing a Oak tree at (35, 42) with color Green and texture 'Rough'
# Drawing a Oak tree at (84, 13) with color Green and texture 'Rough'
# Drawing a Oak tree at (17, 42) with color Green and texture 'Rough'
# Drawing a Oak tree at (100, 87) with color Green and texture 'Rough'
# Drawing a Oak tree at (13, 13) with color Green and texture 'Rough'
# Drawing a Oak tree at (39, 47) with color Green and texture 'Rough'
# Drawing a Oak tree at (53, 89) with color Green and texture 'Rough'
# Drawing a Oak tree at (31, 87) with color Green and texture 'Rough'
# Drawing a Oak tree at (80, 35) with color Green and texture 'Rough'
# Drawing a Oak tree at (38, 4) with color Green and texture 'Rough'
# Drawing a Oak tree at (52, 2) with color Green and texture 'Rough'
# Drawing a Oak tree at (76, 26) with color Green and texture 'Rough'
# Drawing a Oak tree at (17, 85) with color Green and texture 'Rough'
# Drawing a Oak tree at (46, 56) with color Green and texture 'Rough'
# Drawing a Oak tree at (33, 36) with color Green and texture 'Rough'
# Drawing a Oak tree at (38, 4) with color Green and texture 'Rough'
# Drawing a Oak tree at (45, 61) with color Green and texture 'Rough'
# Drawing a Oak tree at (83, 21) with color Green and texture 'Rough'
# Drawing a Oak tree at (47, 31) with color Green and texture 'Rough'
# Drawing a Oak tree at (59, 24) with color Green and texture 'Rough'
# Drawing a Oak tree at (71, 86) with color Green and texture 'Rough'
# Drawing a Oak tree at (50, 72) with color Green and texture 'Rough'
# Drawing a Oak tree at (19, 33) with color Green and texture 'Rough'
# Drawing a Oak tree at (43, 54) with color Green and texture 'Rough'
# Drawing a Oak tree at (67, 26) with color Green and texture 'Rough'
# Drawing a Oak tree at (93, 6) with color Green and texture 'Rough'
# Drawing a Oak tree at (37, 12) with color Green and texture 'Rough'
# Drawing a Oak tree at (8, 79) with color Green and texture 'Rough'
# Drawing a Oak tree at (87, 1) with color Green and texture 'Rough'
# Drawing a Oak tree at (35, 22) with color Green and texture 'Rough'
# Drawing a Oak tree at (23, 64) with color Green and texture 'Rough'
# Drawing a Oak tree at (42, 76) with color Green and texture 'Rough'
# Drawing a Oak tree at (82, 66) with color Green and texture 'Rough'
# Drawing a Oak tree at (93, 100) with color Green and texture 'Rough'
# Drawing a Oak tree at (65, 89) with color Green and texture 'Rough'
# Drawing a Oak tree at (54, 2) with color Green and texture 'Rough'
# Drawing a Oak tree at (98, 48) with color Green and texture 'Rough'
# Drawing a Oak tree at (33, 57) with color Green and texture 'Rough'
# Drawing a Oak tree at (100, 45) with color Green and texture 'Rough'
# Drawing a Oak tree at (17, 77) with color Green and texture 'Rough'
# Drawing a Oak tree at (2, 71) with color Green and texture 'Rough'
# Drawing a Oak tree at (93, 80) with color Green and texture 'Rough'
# Drawing a Oak tree at (24, 77) with color Green and texture 'Rough'
# Drawing a Oak tree at (41, 78) with color Green and texture 'Rough'
# Drawing a Oak tree at (35, 22) with color Green and texture 'Rough'
# Drawing a Oak tree at (55, 81) with color Green and texture 'Rough'
# Drawing a Oak tree at (78, 64) with color Green and texture 'Rough'
# Drawing a Oak tree at (33, 83) with color Green and texture 'Rough'
# Drawing a Oak tree at (45, 77) with color Green and texture 'Rough'
# Drawing a Oak tree at (37, 4) with color Green and texture 'Rough'
# Drawing a Oak tree at (8, 91) with color Green and texture 'Rough'
# Drawing a Oak tree at (56, 5) with color Green and texture 'Rough'
# Drawing a Oak tree at (8, 93) with color Green and texture 'Rough'
# Drawing a Oak tree at (75, 94) with color Green and texture 'Rough'
# Drawing a Oak tree at (74, 35) with color Green and texture 'Rough'
# Drawing a Oak tree at (93, 31) with color Green and texture 'Rough'
# Drawing a Oak tree at (3, 14) with color Green and texture 'Rough'
# Drawing a Oak tree at (65, 47) with color Green and texture 'Rough'
# Drawing a Oak tree at (5, 41) with color Green and texture 'Rough'
# Drawing a Oak tree at (26, 22) with color Green and texture 'Rough'
# Drawing a Oak tree at (8, 76) with color Green and texture 'Rough'
# Drawing a Oak tree at (11, 55) with color Green and texture 'Rough'
# Drawing a Oak tree at (43, 9) with color Green and texture 'Rough'
# Drawing a Oak tree at (22, 48) with color Green and texture 'Rough'
# Drawing a Oak tree at (21, 6) with color Green and texture 'Rough'
# Drawing a Oak tree at (63, 62) with color Green and texture 'Rough'
# Drawing a Oak tree at (50, 46) with color Green and texture 'Rough'
# Drawing a Oak tree at (96, 32) with color Green and texture 'Rough'
# Drawing a Oak tree at (47, 22) with color Green and texture 'Rough'
# Drawing a Oak tree at (72, 70) with color Green and texture 'Rough'
# Drawing a Oak tree at (42, 44) with color Green and texture 'Rough'
# Drawing a Oak tree at (88, 28) with color Green and texture 'Rough'
# Drawing a Oak tree at (64, 99) with color Green and texture 'Rough'
# Drawing a Oak tree at (47, 35) with color Green and texture 'Rough'
# Drawing a Oak tree at (34, 75) with color Green and texture 'Rough'
# Drawing a Oak tree at (53, 52) with color Green and texture 'Rough'
# Drawing a Oak tree at (0, 29) with color Green and texture 'Rough'
# Drawing a Oak tree at (15, 23) with color Green and texture 'Rough'
# Drawing a Oak tree at (36, 85) with color Green and texture 'Rough'
# Drawing a Oak tree at (70, 75) with color Green and texture 'Rough'
# Drawing a Oak tree at (95, 50) with color Green and texture 'Rough'
# Drawing a Oak tree at (67, 51) with color Green and texture 'Rough'
# Drawing a Oak tree at (0, 39) with color Green and texture 'Rough'
# Drawing a Oak tree at (80, 78) with color Green and texture 'Rough'
# Drawing a Oak tree at (71, 84) with color Green and texture 'Rough'
# Drawing a Oak tree at (60, 99) with color Green and texture 'Rough'
# Drawing a Oak tree at (15, 43) with color Green and texture 'Rough'
# Drawing a Oak tree at (90, 79) with color Green and texture 'Rough'
# Drawing a Oak tree at (1, 73) with color Green and texture 'Rough'
# Drawing a Oak tree at (13, 87) with color Green and texture 'Rough'
# Drawing a Oak tree at (16, 78) with color Green and texture 'Rough'
# Drawing a Oak tree at (56, 39) with color Green and texture 'Rough'
# Drawing a Oak tree at (7, 19) with color Green and texture 'Rough'
# Drawing a Oak tree at (49, 13) with color Green and texture 'Rough'
# Drawing a Oak tree at (12, 82) with color Green and texture 'Rough'
# Drawing a Oak tree at (46, 85) with color Green and texture 'Rough'
# Drawing a Oak tree at (38, 18) with color Green and texture 'Rough'
# Drawing a Oak tree at (38, 60) with color Green and texture 'Rough'
# Drawing a Pine tree at (16, 19) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (56, 71) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (36, 43) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (93, 54) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (18, 89) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (26, 37) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (84, 0) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (68, 30) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (34, 13) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (22, 74) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (1, 38) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (87, 29) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (85, 52) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (100, 84) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (26, 63) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (24, 80) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (33, 25) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (72, 17) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (24, 67) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (59, 13) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (43, 62) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (10, 7) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (70, 70) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (13, 94) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (17, 52) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (36, 87) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (85, 17) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (77, 72) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (97, 30) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (6, 89) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (16, 20) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (17, 60) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (63, 9) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (8, 90) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (40, 89) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (74, 3) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (97, 14) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (58, 34) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (58, 31) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (35, 99) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (41, 47) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (50, 50) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (43, 24) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (35, 98) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (15, 42) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (73, 88) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (84, 49) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (13, 13) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (23, 13) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (10, 84) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (11, 57) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (61, 60) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (46, 68) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (66, 36) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (99, 48) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (48, 65) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (38, 82) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (66, 66) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (83, 87) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (28, 57) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (1, 90) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (19, 49) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (19, 15) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (47, 93) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (4, 54) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (79, 97) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (28, 26) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (82, 17) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (81, 91) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (64, 44) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (84, 59) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (24, 66) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (57, 18) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (97, 69) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (82, 26) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (66, 43) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (35, 50) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (0, 70) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (11, 29) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (52, 83) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (27, 67) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (0, 52) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (12, 15) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (95, 80) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (24, 46) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (65, 59) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (18, 77) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (99, 13) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (90, 12) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (57, 34) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (47, 27) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (85, 92) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (14, 13) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (58, 62) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (86, 4) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (67, 83) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (61, 92) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (0, 83) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (19, 23) with color Dark Green and texture 'Pointy'
# Drawing a Pine tree at (98, 28) with color Dark Green and texture 'Pointy'
